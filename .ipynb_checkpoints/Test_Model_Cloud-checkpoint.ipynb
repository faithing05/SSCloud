# %%
import torch

# Проверяем доступность CUDA
if torch.cuda.is_available():
    device_count = torch.cuda.device_count()
    current_device = torch.cuda.current_device()
    device_name = torch.cuda.get_device_name(current_device)
    
    print("🎉 CUDA доступна!")
    print(f"Количество GPU: {device_count}")
    print(f"Текущее устройство: {current_device} ({device_name})")
else:
    print("❗️ CUDA недоступна. Модель будет работать на CPU (медленно).")
    print("❗️ Убедитесь, что вы запустили контейнер с флагом --gpus all.")

# Установим устройство для дальнейшей работы
device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# 🎉 CUDA доступна!
# Количество GPU: 1
# Текущее устройство: 0 (NVIDIA GeForce RTX 3080 Ti)

# %%
# Используем '!' для выполнения команды в терминале из ячейки ноутбука
# Скачиваем тестовое изображение 'truck.jpg' из официального репозитория SAM,
# так как Pexels блокирует прямые запросы.
# !mkdir -p /app/DATA
# !wget -O /app/DATA/truck.jpg "https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/truck.jpg"

print("✅ Изображение 'truck.jpg' успешно скачано в папку /app/DATA/")
# Out:
# --2025-06-11 20:03:58--  https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/truck.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 271475 (265K) [image/jpeg]
# Saving to: ‘/app/DATA/truck.jpg’
#
# /app/DATA/truck.jpg 100%[===================>] 265.11K  --.-KB/s    in 0.05s
#
# 2025-06-11 20:03:58 (5.41 MB/s) - ‘/app/DATA/truck.jpg’ saved [271475/271475]
#
# ✅ Изображение 'truck.jpg' успешно скачано в папку /app/DATA/

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator

# --- 1. Определяем пути ---
# Путь к скачанному изображению
image_path = "/app/DATA/truck.jpg"
# Путь к модели внутри контейнера
model_checkpoint_path = "/app/MODELS/sam_vit_h_4b8939.pth"
model_type = "vit_h"

# --- 2. Загружаем модель ---
print("Загрузка модели... Это может занять несколько секунд.")
sam = sam_model_registry[model_type](checkpoint=model_checkpoint_path)
sam.to(device=device)
print("Модель успешно загружена на", device)

# --- 3. Инициализируем генератор масок ---
# SamAutomaticMaskGenerator найдет все объекты на изображении автоматически
mask_generator = SamAutomaticMaskGenerator(sam)

# --- 4. Загружаем и обрабатываем изображение ---
# OpenCV читает изображения в формате BGR, а модель ожидает RGB
image_bgr = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
print(f"Изображение загружено, его размер: {image_rgb.shape}")

# --- 5. Запускаем сегментацию ---
print("Запуск генерации масок... Это может занять некоторое время на GPU.")
masks = mask_generator.generate(image_rgb)
print(f"✅ Готово! Найдено {len(masks)} масок.")
# Out:
# Загрузка модели... Это может занять несколько секунд.
# Модель успешно загружена на cuda
# Изображение загружено, его размер: (1200, 1800, 3)
# Запуск генерации масок... Это может занять некоторое время на GPU.
# ✅ Готово! Найдено 77 масок.

# %%
import numpy as np
import matplotlib.pyplot as plt

def show_anns_on_image(image_rgb, anns):
    """
    Создает новое изображение, комбинируя исходное с масками.
    """
    if len(anns) == 0:
        return image_rgb

    # Создаем копию изображения, чтобы не изменять оригинал
    img = image_rgb.copy()
    
    # Создаем пустой слой для масок с альфа-каналом (прозрачностью)
    # Формат: RGBA, где A - прозрачность
    overlay = np.zeros((img.shape[0], img.shape[1], 4), dtype=np.uint8)
    
    # Сортируем маски по площади, чтобы большие не перекрывали маленькие
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)

    for ann in sorted_anns:
        m = ann['segmentation']
        # Генерируем случайный цвет для маски
        color_mask = np.random.randint(0, 256, 3) # Случайный RGB цвет
        
        # Применяем цвет к пикселям, которые принадлежат маске
        # Устанавливаем прозрачность в 90 (из 255)
        overlay[m, :3] = color_mask
        overlay[m, 3] = 90  # Alpha-канал (прозрачность)

    # Конвертируем исходное изображение в формат RGBA
    img_rgba = cv2.cvtColor(img, cv2.COLOR_RGB2RGBA)
    
    # Накладываем слой с масками на изображение
    # Используем cv2.addWeighted для корректного смешивания с учетом прозрачности
    # alpha=1.0 для исходного, beta=1.0 для наложения, gamma=0
    final_image = cv2.addWeighted(img_rgba, 1.0, overlay, 1.0, 0)
    
    # Конвертируем обратно в RGB для отображения в matplotlib
    final_image_rgb = cv2.cvtColor(final_image, cv2.COLOR_RGBA2RGB)

    return final_image_rgb

# --- Создаем и отображаем финальное изображение ---
result_image = show_anns_on_image(image_rgb, masks)

plt.figure(figsize=(15, 10))
plt.imshow(result_image)
plt.axis('off')
plt.title("Результаты работы Segment Anything на 'truck.jpg'")
plt.show()

# %%
# Убедитесь, что эти библиотеки импортированы
import cv2
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Укажите путь к вашей фотографии ---
# Файл должен находиться в папке /app/CODE/
image_path = "/app/CODE/Vistino20241014_E57/1_normals.jpg"  # <-- ИЗМЕНИТЕ ЭТО ИМЯ на имя вашего файла!

# --- 2. Загружаем и обрабатываем ваше изображение ---
# Модель и генератор масок уже загружены в память, их не нужно создавать заново
try:
    image_bgr = cv2.imread(image_path)
    # Проверяем, что изображение успешно загрузилось
    if image_bgr is None:
        raise FileNotFoundError(f"Не удалось загрузить изображение. Проверьте путь: {image_path}")
        
    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
    print(f"Ваше изображение '{image_path.split('/')[-1]}' успешно загружено. Размер: {image_rgb.shape}")

    # --- 3. Запускаем сегментацию ---
    print("Запускаю сегментацию вашего изображения...")
    masks = mask_generator.generate(image_rgb)
    print(f"✅ Готово! Найдено {len(masks)} масок.")

    # --- 4. Визуализируем результат ---
    # Используем ту же функцию, что и для грузовика
    result_image = show_anns_on_image(image_rgb, masks)

    plt.figure(figsize=(15, 10))
    plt.imshow(result_image)
    plt.axis('off')
    plt.title(f"Результаты сегментации для '{image_path.split('/')[-1]}'")
    plt.show()

except FileNotFoundError as e:
    print(e)

# %%
# Посмотрим, сколько всего масок
print(f"Всего масок: {len(masks)}")

# Посмотрим, какие ключи (какая информация) есть для каждой маски
# Возьмем первую маску в качестве примера (индекс 0)
if len(masks) > 0:
    print("\nКлючи для одной маски:")
    print(list(masks[0].keys()))

# %%
# --- ВЫБЕРИТЕ ИНДЕКС МАСКИ ДЛЯ ИССЛЕДОВАНИЯ ---
mask_index = 3  # Попробуйте менять это число от 0 до 34

# Получаем данные для выбранной маски
single_mask_data = masks[mask_index]

# Извлекаем саму маску (2D массив True/False)
mask = single_mask_data['segmentation']

# Извлекаем ее площадь и рамку
area = single_mask_data['area']
bbox = single_mask_data['bbox']

print(f"Исследуем маску с индексом {mask_index}")
print(f"Ее площадь: {area} пикселей")
print(f"Ее рамка (bbox): {bbox}")

# Рисуем только эту маску
plt.figure(figsize=(10, 10))
plt.imshow(mask, cmap='gray') # cmap='gray' покажет ее в черно-белом виде
plt.axis('off')
plt.title(f"Маска №{mask_index}")
plt.show()

# Используем ту же выбранную маску из ячейки выше
# (убедитесь, что mask_index, mask, image_rgb существуют)

# Создаем цветную версию маски (например, ярко-красную)
highlight_color = [255, 0, 0] # Красный
highlight_mask = np.zeros_like(image_rgb)
highlight_mask[mask] = highlight_color

# Смешиваем исходное изображение с нашей подсветкой
# 0.6 и 0.4 - коэффициенты прозрачности
highlighted_image = cv2.addWeighted(image_rgb, 0.6, highlight_mask, 0.4, 0)

plt.figure(figsize=(15, 10))
plt.imshow(highlighted_image)
plt.axis('off')
plt.title(f"Подсветка маски №{mask_index}")
plt.show()
